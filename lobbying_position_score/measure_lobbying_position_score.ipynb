# %% [markdown]
# # Lobbying Position Score

# %%
library(mirt)
library(ggplot2)
library(parallel)

rm(list=ls(all=TRUE))
source("utils.r")
# Out:
# Loading required package: stats4
#
# Loading required package: lattice

# %%
score_input_path <- 'score_input'
input_file_name  <- 'interest_group_bill_bill_position_input_df'
score_output_path <- 'score_output'
dim <- 1
itemtype <- 'graded'

# %%
model <- pipeline_score_df(score_input_path, input_file_name, score_output_path, dim, itemtype)
# Out:
# Iteration: 500, Log-Lik: -201115.246, Max-Change: 0.00036
# Warning message:
# “EM cycles terminated after 500 iterations.”
# Warning message:
# “Unable to compute normalization constant for EAP estimates; consider using MAP estimates instead. Returning NaNs”
# Warning message:
# “Unable to compute normalization constant for EAP estimates; consider using MAP estimates instead. Returning NaNs”
# Warning message:
# “Unable to compute normalization constant for EAP estimates; consider using MAP estimates instead. Returning NaNs”
# Warning message:
# “Unable to compute normalization constant for EAP estimates; consider using MAP estimates instead. Returning NaNs”
# Warning message:
# “Unable to compute normalization constant for EAP estimates; consider using MAP estimates instead. Returning NaNs”
# Warning message:
# “Unable to compute normalization constant for EAP estimates; consider using MAP estimates instead. Returning NaNs”
# Warning message:
# ...

# %% [markdown]
# #### Get reliability score

# %%
get_reliability(model)
# Out:
# Warning message:
# “Unable to compute normalization constant for EAP estimates; consider using MAP estimates instead. Returning NaNs”
# Warning message:
# “Unable to compute normalization constant for EAP estimates; consider using MAP estimates instead. Returning NaNs”
# Warning message:
# “Unable to compute normalization constant for EAP estimates; consider using MAP estimates instead. Returning NaNs”
# Warning message:
# “Unable to compute normalization constant for EAP estimates; consider using MAP estimates instead. Returning NaNs”
# Warning message:
# “Unable to compute normalization constant for EAP estimates; consider using MAP estimates instead. Returning NaNs”
# Warning message:
# “Unable to compute normalization constant for EAP estimates; consider using MAP estimates instead. Returning NaNs”
# Warning message:
# “Unable to compute normalization constant for EAP estimates; consider using MAP estimates instead. Returning NaNs”
# Warning message:
# ...

# %% [markdown]
# #### Get standard Error

# %%
get_standard_error(model)
# Out:
#  [1] 0.05405256 0.05181342 0.04965155 0.04755472 0.04550909 0.04350612
#  [7] 0.04154486 0.03963012 0.03776998 0.03597672 0.03427403 0.03270426
# [13] 0.03131012 0.03009683 0.02904766 0.02818518 0.02760306 0.02746058
# [19] 0.02795911 0.02928171 0.03154064 0.03481791 0.03919936 0.04475600
# [25] 0.05153098 0.05954706 0.06881799 0.07935434 0.09116353 0.10424565
# [31] 0.11858608 0.13414509 0.15084418 0.16854897 0.18704884 0.20603500
# [37] 0.22508047 0.24362869 0.26100010 0.27642688 0.28912186 0.29837675
# [43] 0.30366989 0.30475230 0.30168307 0.29480272 0.28465689 0.27189859
# [49] 0.25719771 0.24117540 0.22436783 0.20721448 0.19006271 0.17318083
# [55] 0.15677413 0.14100023 0.12598235 0.11181956 0.09859426 0.08637682
# [61] 0.07522791 0.06519889 0.05633169 0.04866096 0.04222338 0.03707399
# [67] 0.03327834 0.03081819 0.02947649 0.02891326 0.02886043 0.02918990
# [73] 0.02985073 0.03079539 0.03195525 0.03325690 0.03464350 0.03608170
# [79] 0.03755643 0.03906236 0.04059756
# ...
